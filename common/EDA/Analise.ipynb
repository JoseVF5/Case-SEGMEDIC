# %% [markdown]
# 1️⃣ Estrutura do Dataset

# %%
import numpy as np
import pandas as pd

# %%
path_csv = r'/home/jvdata/Documentos/Case-SEGMEDIC/src/data/prata/Dados_limpos.csv'

# %% [markdown]
# - Carregar o data set

# %%
df_limpo = pd.read_csv(path_csv, sep=";")

# %% [markdown]
# - Exibir as 5 Primeiras Linhas

# %%
df_limpo.head(6)
# Out:
#   Data_Atendimento  ID_paciente       Nome_procedimento  \
# 0       2024-01-30       104593   Rx Tornozelo Esquerdo
# 1       2024-01-30       104593               Rx Joelho
# 2       2024-02-06       166899  Consulta Clinica Geral
# 3       2024-02-22       188620  Consulta Clinica Geral
# 4       2024-02-26        45111  Consulta Clinica Geral
# 5       2024-03-27        18877  Consulta Clinica Geral
#
#   Categoria_procedimento  valor_pago retorno               Unidade  \
# 0                 Raio X        49.0     Não  Centro Medico Matriz
# 1                 Raio X        49.0     Não  Centro Medico Matriz
# 2          Clinica Geral        19.0     Não  Centro Medico Matriz
# 3          Clinica Geral        19.0     Não  Centro Medico Matriz
# 4          Clinica Geral        19.0     Não  Centro Medico Matriz
# 5          Clinica Geral        19.0     Não  Centro Medico Matriz
#
#   Metodo_pagamento  ID_profissional
# 0              PIX            18252
# 1              PIX            18252
# 2              PIX            18052
# 3              PIX            18190
# 4              PIX            18188
# 5              PIX            17955

# %% [markdown]
# - Quantas linhas e colunas existem no arquivo?

# %%
df_limpo.shape
# Out:
# (5050, 9)

# %% [markdown]
# Linhas = 5050
# Colunas = 9

# %% [markdown]
# 2️⃣ Valor Atendido por Mês

# %% [markdown]
# - Qual o valor total atendido por mês?

# %%
#houve um erro na mudança de data type da coluna. corrigir repetindo o processo de mudança de data type.

df_limpo['Data_Atendimento'] = pd.to_datetime(df_limpo['Data_Atendimento'])

# %%
df_limpo.dtypes
# Out:
# Data_Atendimento          datetime64[us]
# ID_paciente                        int64
# Nome_procedimento                    str
# Categoria_procedimento               str
# valor_pago                       float64
# retorno                              str
# Unidade                              str
# Metodo_pagamento                     str
# ID_profissional                    int64
# dtype: object

# %%
valor_mes_agrupado = df_limpo.groupby(pd.Grouper(key='Data_Atendimento', freq='ME'))['valor_pago'].agg(['sum', 'mean'])

# %% [markdown]
# ME = Mounth End

# %%
valor_mes_agrupado = valor_mes_agrupado.rename(columns={
    'sum': 'Soma_Total', 
    'mean': 'Media_Mensal'
})
valor_mes_agrupado.head()
# Out:
#                   Soma_Total  Media_Mensal
# Data_Atendimento
# 2024-01-31         510263.75   1457.896429
# 2024-02-29           7544.13     25.924845
# 2024-03-31          12312.81     27.983659
# 2024-04-30           7627.93     25.683266
# 2024-05-31           9444.45     27.139224

# %% [markdown]
# Soma total:
# - Janeiro = 510.263,75
# - Fevereiro = 7.544,13
# - Março = 12.312,81
# - Abril = 7.627,93
# - Maio = 9.444,45

# %% [markdown]
# 3️⃣ Quantidade de Atendimentos por Mês

# %% [markdown]
# - Quantos atendimentos ocorreram em cada mês?

# %%
atendimento_mes = df_limpo.groupby(pd.Grouper(key='Data_Atendimento', freq='ME'))['ID_paciente'].count()
atendimento_mes.head()
# Out:
# Data_Atendimento
# 2024-01-31    350
# 2024-02-29    291
# 2024-03-31    440
# 2024-04-30    297
# 2024-05-31    348
# Freq: ME, Name: ID_paciente, dtype: int64

# %% [markdown]
# 4️⃣ Pacientes com Maior Frequência
